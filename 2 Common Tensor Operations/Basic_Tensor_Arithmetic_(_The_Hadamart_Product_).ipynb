# %%
import numpy as np
import torch
import tensorflow as tf

# %%
X = np.array([[7, 4, 11], [14, 8, 22]])
X

# %%
X*2

# %%
X+5

# %%
X-4

# %%
X_pt = torch.tensor([[5, 3, 9], [10, 6, 18]])
X_pt

# %%
X_pt*2

# %%
X_pt+6

# %%
X_pt-2

# %%
X_tf = tf.Variable([[9, 8, 13], [18, 4, 26]])
X_tf

# %%
X_tf*3

# %%
X_tf+5

# %%
X_tf-3

# %%
Y = np.array([[5, 15, 23], [16, 3, 8]])
Y

# %%
Y_pt = torch.tensor([[4, 2, 6], [12, 6, 18]])
Y_pt

# %%
Y_tf = tf.Variable([[3, 6, 9], [7, 14, 21]])
Y_tf

# %%
X * Y

# %%
X_pt * Y_pt

# %%
X_tf * Y_tf
