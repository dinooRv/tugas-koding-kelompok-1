# %%
import numpy as np
import torch
import tensorflow as tf

# %%
X = np.array([[12, 3, 6], [25, 8, 9]])
X

# %%
X_pt = torch.tensor([[15, 9, 6], [4, 3, 19]])
X_pt

# %%
X_tf = tf.Variable([[4, 8, 16], [3, 9, 18]])
X_tf

# %%
X.T

# %%
X_pt.T

# %%
tf.transpose(X_tf)
